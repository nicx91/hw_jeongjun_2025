# %% [markdown]
# # Boolean Popcorn Hacks
# <hr>

# %% [markdown]
# ## De Morgan's Law

# %% [markdown]
# <p>Using De Morgan’s Law you can simplify the following,<p>
# <p>!(A && B) === (!A || !B)<p>
# <p>!(A || B) === (!A && !B)<p>

# %% [markdown]
# ## Usage

# %% [markdown]
# <p>Without De Morgan’s Law:<p>

# %%
# %%js
#
# function check() {
#    if (!(a || b || c)) {
#     return false;
#    }
#     return true; }

# %% [markdown]
# <p>This function returns false only if all are false. If at least one is true then the function returns true.<p>
#
# <p>Using De Morgan’s Law:<p>

# %%
# %%js
#
# function checkC() {
#     return a || b || c;
#
# }

# %% [markdown]
# <p>This function returns if at least one is true. Using De Morgan’s Law we can write the same code in a shorter simpler way that makes it easier to read and comprehend.<p>

# %% [markdown]
# ## Example

# %%
# %%js
# //You can run this code to see what's happening
#
# let fat = false;
# let short = false;
# let badPersonality = false;
#
# console.log("Welcome to the person test.");
# console.log("You can put your bad points in the code and I will guess what kind of person are you.");
# console.log("Be honest :)");
# if (fat && short && badPersonality) {
#     console.log("yo wassup ryan");
# } else if (fat || short || badPersonality) {
#     console.log("You think you have a bad point to you. But I can see that you can fix the problem. You can do it!");
# } else if (!(fat && short && badPersonality)) {
#     console.log("You're thinking you don't have any bad points. Great keep it on!");
# }

# %% [markdown]
# ## Popcorn Hack
#
# #### Instruction:
#
# 1. Make three boolean variable `ID`, `passcode`, `verificationCode`.
#
# 2. Make it log in when these all three variable is true.
#
# 3. Make another three boolean variable with name of your directory (or you can make it up).
#
# 4. Print that your directory is opened if one of the variable is true.
